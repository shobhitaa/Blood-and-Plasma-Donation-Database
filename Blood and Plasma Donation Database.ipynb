# %%
from tkinter import *
from tkinter import messagebox
from PIL import ImageTk,Image
import pymysql
from datetime import datetime

my_password = "password"
my_database = "blood_plasma_donation"

con = pymysql.connect(host = "localhost", user = "root", password = my_password, database = my_database)
cur = con.cursor()

# %%
##--------------------------------------------------Blood Bank--------------------------------------------------##

BloodBank_Table = "BloodBank"

def BloodBankRegister():
    
    bid = BBInfo1.get()
    bname = BBInfo2.get()
    bcontact = BBInfo3.get()
    blocation = BBInfo4.get()
    if BBInfo5.get() == "":
        insertBB = "insert into "+BloodBank_Table+"(B_ID, B_Name, Contact_no, B_Location) values('"+bid+"','"+bname+"','"+bcontact+"','"+blocation+"')"
    else:
        A_ID = BBInfo5.get()
        H_ID = BBInfo6.get()
        insertBB = "insert into "+BloodBank_Table+" values('"+bid+"','"+bname+"','"+bcontact+"','"+blocation+"','"+A_ID+"','"+H_ID+"')"
        
    try:
        cur.execute(insertBB)
        con.commit()
        messagebox.showinfo('Success',"Blood Bank added successfully")
    except:
        messagebox.showinfo("Error","Can't add data into Database")

    root.destroy()
    
def RemoveBloodBank():
    
    bid = BBRem.get()
    BloodBank_Table = "BloodBank"
    Takes_from_Table = "Takes_from"
    Gives_to_Table = "Gives_to"

    deleteDetails = "delete from "+Takes_from_Table+" where B_id = '"+bid+"'"
    deleteBB = "delete from "+BloodBank_Table+" where B_ID = '"+bid+"'"
    deleteG = "delete from "+Gives_to_Table+" where B_ID = '"+bid+"'"
    
    try:
        cur.execute(deleteG)
        con.commit()
        cur.execute(deleteDetails)
        con.commit()
        cur.execute(deleteBB)
        con.commit()
        messagebox.showinfo('Success',"Blood Bank Deleted Successfully")
    except:
        messagebox.showinfo('Error', "Please check Blood Bank ID")

    BBRem.delete(0, END)
    root.destroy()

def View_BloodBank():
    
    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()
    
    root = Tk()
    root.title("Blood Bank")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")


    Canvas1 = Canvas(root) 
    Canvas1.config(bg="#738786")
    Canvas1.pack(expand=True,fill=BOTH)
        
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Blood Banks", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    y = 0.25
    
    Label(labelFrame, text="%-25s%-50s%-35s%-40s"%('Blood Bank ID','Name','Contact No.','Location'),bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text="-----------------------------------------------------------------------------------------------",bg='black',fg='white').place(relx=0.05,rely=0.2)
    getBloodBanks = "select * from "+BloodBank_Table
    try:
        cur.execute(getBloodBanks)
        con.commit()
        for i in cur:
            Label(labelFrame, text="%-30s%-52s%-35s%-40s"%(i[0],i[1],i[2],i[3]),bg='black',fg='white').place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    AddBtn = Button(root,text="Add",bg='#EC9DA3', fg='black',command=add_BB)
    AddBtn.place(relx=0.21,rely=0.9, relwidth=0.18,relheight=0.08)
    
    RemoveBtn = Button(root,text="Remove",bg='#EC9DA3', fg='black', command=delete_BloodBank)
    RemoveBtn.place(relx=0.41,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.61,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
    
def add_BB(): 
    
    global BBInfo1,BBInfo2,BBInfo3,BBInfo4,BBInfo5,BBInfo6,Canvas1,con,cur,BloodBank_Table,root
    
    root = Tk()
    root.title("Blood Bank")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    my_password = "password"
    my_database = "blood_plasma_donation"

    BloodBank_Table = "BloodBank"
    
    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#738786")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

    headingLabel = Label(headingFrame1, text="Add Blood Bank", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    # Blood Bank ID
    lb1 = Label(labelFrame,text="Blood Bank ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.1, relheight=0.08)
        
    BBInfo1 = Entry(labelFrame)
    BBInfo1.place(relx=0.3,rely=0.1, relwidth=0.62, relheight=0.08)
        
    # Name
    lb2 = Label(labelFrame,text="Name : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.25, relheight=0.08)
        
    BBInfo2 = Entry(labelFrame)
    BBInfo2.place(relx=0.3,rely=0.25, relwidth=0.62, relheight=0.08)
    
    # Contact
    lb3 = Label(labelFrame,text="Contact No. : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.40, relheight=0.08)
        
    BBInfo3 = Entry(labelFrame)
    BBInfo3.place(relx=0.3,rely=0.40, relwidth=0.62, relheight=0.08)
        
    # Location
    lb4 = Label(labelFrame,text="Location : ", bg='black', fg='white')
    lb4.place(relx=0.05,rely=0.55, relheight=0.08)
        
    BBInfo4 = Entry(labelFrame)
    BBInfo4.place(relx=0.3,rely=0.55, relwidth=0.62, relheight=0.08)
        
    # Admin ID
    lb5 = Label(labelFrame,text="Admin ID : ", bg='black', fg='white')
    lb5.place(relx=0.05,rely=0.7, relheight=0.08)
        
    BBInfo5 = Entry(labelFrame)
    BBInfo5.place(relx=0.3,rely=0.7, relwidth=0.62, relheight=0.08)
    
    # Hospital ID
    lb6 = Label(labelFrame,text="Hospital ID : ", bg='black', fg='white')
    lb6.place(relx=0.05,rely=0.85, relheight=0.08)
        
    BBInfo6 = Entry(labelFrame)
    BBInfo6.place(relx=0.3,rely=0.85, relwidth=0.62, relheight=0.08)
        
    #Submit Button
    SubmitBtn = Button(root,text="SUBMIT",bg='#EC9DA3', fg='black',command=BloodBankRegister)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
    
def delete_BloodBank(): 
    
    global BBRem,Canvas1,con,cur,Hospital_Table,root
    
    root = Tk()
    root.title("Blood Bank")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#738786")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Remove Blood Bank", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)   
        
    # BloodBank ID to Delete
    lb2 = Label(labelFrame,text="Blood Bank ID : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.5)
        
    BBRem = Entry(labelFrame)
    BBRem.place(relx=0.3,rely=0.5, relwidth=0.62)
    
    SubmitBtn = Button(root,text="Remove",bg='#EC9DA3', fg='black',command=RemoveBloodBank)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
##--------------------------------------------------HOSPITAL--------------------------------------------------##

Hospital_Table = "Hospital"

def HospitalRegister():
    
    hid = HospitalInfo1.get()
    Hname = HospitalInfo2.get()
    Hlocation = HospitalInfo3.get()
    if HospitalInfo4.get() == "":
        insertHospital = "insert into "+Hospital_Table+"(H_ID, HName, Location) values('"+hid+"','"+Hname+"','"+Hlocation+"')"
    else:
        A_ID = HospitalInfo4.get()
        insertHospital = "insert into "+Hospital_Table+" values('"+hid+"','"+Hname+"','"+Hlocation+"','"+A_ID+"')"
        
    try:
        cur.execute(insertHospital)
        con.commit()
        messagebox.showinfo('Success',"Hospital added successfully")
    except:
        messagebox.showinfo("Error","Can't add data into Database")

    root.destroy()
    
def RemoveHospital():
    
    hid = HospitalRem.get()
    BloodBank_Table = "BloodBank"
    Patient_Table = "Patients"
    Takes_from_Table = "Takes_from"
    Gives_to_Table = "Gives_to"

    deleteDetails = "delete from "+Takes_from_Table+" where B_ID in (select B_ID from "+BloodBank_Table+" where H_ID = '"+hid+"')"
    deleteG = "delete from "+Gives_to_Table+" where B_ID in (select B_ID from "+BloodBank_Table+" where H_ID = '"+hid+"')"
    deleteP = "delete from "+Patient_Table+" where H_id = '"+hid+"'"
    deleteBB = "delete from "+BloodBank_Table+" where H_id = '"+hid+"'"
    deleteH = "delete from "+Hospital_Table+" where H_id = '"+hid+"'"

    try:
        cur.execute(deleteDetails)
        con.commit()
        cur.execute(deleteG)
        con.commit()
        cur.execute(deleteP)
        con.commit()
        cur.execute(deleteBB)
        con.commit()
        cur.execute(deleteH)
        con.commit()
        messagebox.showinfo('Success',"Hospital Deleted Successfully")
    except:
        messagebox.showinfo('Error',"Please check Hospital ID")

    HospitalRem.delete(0, END)
    root.destroy()
    

def View_Hospital(): 
    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()
    
    root = Tk()
    root.title("Hospital")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")


    Canvas1 = Canvas(root) 
    Canvas1.config(bg="#738786")
    Canvas1.pack(expand=True,fill=BOTH)
        
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Hospitals", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    y = 0.25
    
    Label(labelFrame, text="%-25s%-50s%-30s%-40s"%('Hospital ID','Name','Location','Admin ID'),bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text="-----------------------------------------------------------------------------------------",bg='black',fg='white').place(relx=0.05,rely=0.2)
    getHospitals = "select * from "+Hospital_Table
    try:
        cur.execute(getHospitals)
        con.commit()
        for i in cur:
            Label(labelFrame, text="%-30s%-52s%-35s%-40s"%(i[0],i[1],i[2],i[3]),bg='black',fg='white').place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    AddBtn = Button(root,text="Add",bg='#EC9DA3', fg='black',command=add_Hospital)
    AddBtn.place(relx=0.21,rely=0.9, relwidth=0.18,relheight=0.08)
    
    RemoveBtn = Button(root,text="Remove",bg='#EC9DA3', fg='black', command=delete_Hospital)
    RemoveBtn.place(relx=0.41,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.61,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
    
def add_Hospital(): 
    
    global HospitalInfo1,HospitalInfo2,HospitalInfo3,HospitalInfo4,Canvas1,con,cur,Hospital_Table,root
    
    root = Tk()
    root.title("Hospital")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()


    Hospital_Table = "Hospital"

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#738786")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

    headingLabel = Label(headingFrame1, text="Add Hospital", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    # Hospital ID
    lb1 = Label(labelFrame,text="Hospital ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2, relheight=0.08)
        
    HospitalInfo1 = Entry(labelFrame)
    HospitalInfo1.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
        
    # Name
    lb2 = Label(labelFrame,text="Name : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.35, relheight=0.08)
        
    HospitalInfo2 = Entry(labelFrame)
    HospitalInfo2.place(relx=0.3,rely=0.35, relwidth=0.62, relheight=0.08)
        
    # Location
    lb3 = Label(labelFrame,text="Location : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.50, relheight=0.08)
        
    HospitalInfo3 = Entry(labelFrame)
    HospitalInfo3.place(relx=0.3,rely=0.50, relwidth=0.62, relheight=0.08)
        
    # Admin ID
    lb4 = Label(labelFrame,text="Admin ID : ", bg='black', fg='white')
    lb4.place(relx=0.05,rely=0.65, relheight=0.08)
        
    HospitalInfo4 = Entry(labelFrame)
    HospitalInfo4.place(relx=0.3,rely=0.65, relwidth=0.62, relheight=0.08)
        
    SubmitBtn = Button(root,text="SUBMIT",bg='#EC9DA3', fg='black',command=HospitalRegister)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
    
def delete_Hospital(): 
    
    global HospitalRem,Canvas1,con,cur,Hospital_Table,root
    
    root = Tk()
    root.title("Hospital")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#738786")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Remove Hospital", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)   
        
    # Hospital ID to Delete
    lb2 = Label(labelFrame,text="Hospital ID : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.5)
        
    HospitalRem = Entry(labelFrame)
    HospitalRem.place(relx=0.3,rely=0.5, relwidth=0.62)

    SubmitBtn = Button(root,text="Remove",bg='#EC9DA3', fg='black',command=RemoveHospital)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
##--------------------------------------------------DONOR--------------------------------------------------##

def DonorRegister():
    
    Did = DInfo1.get()
    DFname = DInfo2.get()
    DLname = DInfo3.get()
    DBG = DInfo4.get()
    DAge = DInfo5.get()
    DGender = DInfo6.get()
    Dcontact = DInfo7.get()
    #Demail = DInfo8.get()
    Dadd = DInfo9.get()
    bid = DInfo10.get()
    donation = DInfo11.get()
    donation = donation.lower()
    Ddate = DInfo12.get()
    
    Takes_from_Table = "Takes_from"
    
    insertD = "insert into "+Donor_Table+" values('"+Did+"','"+DFname+"','"+DLname+"','"+DBG+"','"+DAge+"','"+DGender+"','"+Dcontact+"','"+Dadd+"')"
    insertDetails = "insert into "+Takes_from_Table+" values('"+bid+"','"+Did+"','"+donation+"','"+Ddate+"')" 
    
    try:
        cur.execute(insertD)
        con.commit()
        cur.execute(insertDetails)
        con.commit()
        messagebox.showinfo('Success',"Donor added successfully")
    except:
        messagebox.showinfo("Error","Can't add data into Database")
        

        
def RemoveDonor():
    
    hid = DonorRem.get()
    Takes_from_Table = "Takes_from"
    Donor_Table = "Donor"
    deleteH = "delete from "+Donor_Table+" where D_id = '"+hid+"'"
    deleteDetails = "delete from "+Takes_from_Table+" where D_id = '"+hid+"'"

    try:
        cur.execute(deleteDetails)
        con.commit()
        cur.execute(deleteH)
        con.commit()
        messagebox.showinfo('Success',"Donor Deleted Successfully")
    except:
        messagebox.showinfo('Error',"Please check Donor ID")

    DonorRem.delete(0, END)
    root.destroy()       

        
def View_Donor(): 
    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()
    
    root = Tk()
    root.title("Donors")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Donor_Table = "Donor"

    Canvas1 = Canvas(root) 
    Canvas1.config(bg="#EC9CA4")
    Canvas1.pack(expand=True,fill=BOTH)
        
        
    headingFrame1 = Frame(root,bg="#8897B0",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Donors", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    y = 0.25
    
    Label(labelFrame, text="%-20s%-40s%-30s%-20s%-20s%-20s"%('Donor ID','Name','Blood Group','Age','Gender','Phone No'),bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text="------------------------------------------------------------------------------------------------------------------",bg='black',fg='white').place(relx=0.05,rely=0.2)
    getDonors = "select * from "+Donor_Table
    try:
        cur.execute(getDonors)
        con.commit()
        for i in cur:
            Label(labelFrame, text="%-30s%-45s%-40s%-25s%-30s%-30s"%(i[0],i[1]+" "+i[2],i[3],i[4],i[5],i[6]),bg='black',fg='white').place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    AddBtn = Button(root,text="Add",bg='#8897B0', fg='black',command=add_Donor)
    AddBtn.place(relx=0.21,rely=0.9, relwidth=0.18,relheight=0.08)
    
    RemoveBtn = Button(root,text="Remove",bg='#8897B0', fg='black', command=delete_Donor)
    RemoveBtn.place(relx=0.41,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#8897B0', fg='black', command=root.destroy)
    quitBtn.place(relx=0.61,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

def add_Donor(): 
    
    global DInfo1,DInfo2,DInfo3,DInfo4,DInfo5,DInfo6,DInfo10,DInfo11,DInfo12,DInfo7,DInfo9,Canvas1,con,cur,Donor_Table,root
    
    root = Tk()
    root.title("Donor Details")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    my_password = "password"
    my_database = "blood_plasma_donation"

    Donor_Table = "Donor"
    
    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#F1BEB6")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#51B3AF",bd=5)
    headingFrame1.place(relx=0.25,rely=0.05,relwidth=0.5,relheight=0.10)

    headingLabel = Label(headingFrame1, text="Donor Details", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.17,relwidth=0.8,relheight=0.7)
        
    # Donor ID
    lb1 = Label(labelFrame,text="Donor ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.02, relheight=0.08)
        
    DInfo1 = Entry(labelFrame)
    DInfo1.place(relx=0.3,rely=0.02, relwidth=0.62, relheight=0.08)
        
    # First Name
    lb2 = Label(labelFrame,text="First Name : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.11, relheight=0.08)
        
    DInfo2 = Entry(labelFrame)
    DInfo2.place(relx=0.3,rely=0.11, relwidth=0.62, relheight=0.08)
    
    # Last Name
    lb3 = Label(labelFrame,text="Last Name : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.20, relheight=0.08)
        
    DInfo3 = Entry(labelFrame)
    DInfo3.place(relx=0.3,rely=0.20, relwidth=0.62, relheight=0.08)
        
    # Blood Group
    lb4 = Label(labelFrame,text="Blood Group : ", bg='black', fg='white')
    lb4.place(relx=0.05,rely=0.29, relheight=0.08)
        
    DInfo4 = Entry(labelFrame)
    DInfo4.place(relx=0.3,rely=0.29, relwidth=0.62, relheight=0.08)
    
    # Blood Bank ID
    lb10 = Label(labelFrame,text="Blood Bank ID : ", bg='black', fg='white')
    lb10.place(relx=0.05,rely=0.38, relheight=0.08)
        
    DInfo10 = Entry(labelFrame)
    DInfo10.place(relx=0.3,rely=0.38, relwidth=0.62, relheight=0.08)
    
    # Donation
    lb11 = Label(labelFrame,text="Blood/Plasma : ", bg='black', fg='white')
    lb11.place(relx=0.05,rely=0.47, relheight=0.08)
        
    DInfo11 = Entry(labelFrame)
    DInfo11.place(relx=0.3,rely=0.47, relwidth=0.62, relheight=0.08)
    
    # Donation Date
    lb12 = Label(labelFrame,text="Donation Date : ", bg='black', fg='white')
    lb12.place(relx=0.05,rely=0.56, relheight=0.08)
        
    DInfo12 = Entry(labelFrame)
    DInfo12.place(relx=0.3,rely=0.56, relwidth=0.62, relheight=0.08)
        
    # Age
    lb5 = Label(labelFrame,text="Age : ", bg='black', fg='white')
    lb5.place(relx=0.05,rely=0.65, relheight=0.08)
        
    DInfo5 = Entry(labelFrame)
    DInfo5.place(relx=0.3,rely=0.65, relwidth=0.62, relheight=0.08)
    
    # Gender
    lb6 = Label(labelFrame,text="Gender : ", bg='black', fg='white')
    lb6.place(relx=0.05,rely=0.74, relheight=0.08)
        
    DInfo6 = Entry(labelFrame)
    DInfo6.place(relx=0.3,rely=0.74, relwidth=0.62, relheight=0.08)
    
    # Contact No.
    lb7 = Label(labelFrame,text="Phone No. : ", bg='black', fg='white')
    lb7.place(relx=0.05,rely=0.83, relheight=0.08)
        
    DInfo7 = Entry(labelFrame)
    DInfo7.place(relx=0.3,rely=0.83, relwidth=0.62, relheight=0.08)
    
    # Address
    lb9 = Label(labelFrame,text="Address : ", bg='black', fg='white')
    lb9.place(relx=0.05,rely=0.92, relheight=0.08)
        
    DInfo9 = Entry(labelFrame)
    DInfo9.place(relx=0.3,rely=0.92, relwidth=0.62, relheight=0.08)
    
    AddBtn = Button(root,text="Add",bg='#51B3AF', fg='black',command=DonorRegister)
    AddBtn.place(relx=0.11,rely=0.9, relwidth=0.18,relheight=0.08)
    
    oldBtn = Button(root,text="Donated before?", bg='#51B3AF', fg='black', command = old_donor_view)
    oldBtn.place(relx=0.31,rely=0.9, relwidth=0.18,relheight=0.08)
    
    ViewBtn = Button(root,text="View Blood Banks",bg='#51B3AF', fg='black', command=View_BloodBank)
    ViewBtn.place(relx=0.51,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#51B3AF', fg='black', command=root.destroy)
    quitBtn.place(relx=0.71,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
    
def delete_Donor(): 
    
    global DonorRem,Canvas1,con,cur,Donor_Table,root
    
    root = Tk()
    root.title("Remove Donor")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#F1BEB6")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#CEDEDB",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Remove Donor", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)   
        
    # Donor ID to Delete
    lb2 = Label(labelFrame,text="Donor ID : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.5)
        
    DonorRem = Entry(labelFrame)
    DonorRem.place(relx=0.3,rely=0.5, relwidth=0.62)
    
    #Submit Button
    SubmitBtn = Button(root,text="Remove",bg='#CEDEDB', fg='black',command=RemoveDonor)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#CEDEDB', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

def old_donor():
    
    did = odInfo1.get()
    bid = odInfo2.get()
    donation = odInfo3.get()
    date = odInfo4.get()
    
    Takes_from_Table = "Takes_from"
    
    update = "update "+Takes_from_Table+" set Donation = '"+donation+"', DonationDate = '"+date+"', B_ID = '"+bid+"' where D_ID = '"+did+"'"
    
    check = "select DonationDate from "+Takes_from_Table+" where D_ID = '"+did+"'"
    cur.execute(check)
    con.commit()
    
    for i in cur:
        year = i[0].strftime("%Y")
        month = i[0].strftime("%m")
        day = i[0].strftime("%d")
        date_time = i[0].strftime("%Y/%m/%d")
        
        check_date = "SELECT DATEDIFF('"+date_time+"', '"+date+"')"
        cur.execute(check_date)
        con.commit()
        
        for j in cur:
            if (j[0] < -95):
                try:
                    cur.execute(update)
                    con.commit()
                    messagebox.showinfo('Success',"Details updated successfully")
                except:
                    messagebox.showinfo("Error","Can't update Database")
            else:
                messagebox.showinfo("Error","Can't donate before 3 months from last donation date")
                break
                
def old_donor_view():
    
    global odInfo1,odInfo2,odInfo3,odInfo4,Canvas1,con,cur,Donor_Table,root
    
    root = Tk()
    root.title("Donate")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()

    Donor_Table = "Donor"

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#F1BEB6")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#51B3AF",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

    headingLabel = Label(headingFrame1, text="Donate", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
        
    # Donor ID
    lb1 = Label(labelFrame,text="Donor ID : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2, relheight=0.08)
        
    odInfo1 = Entry(labelFrame)
    odInfo1.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
        
    # Blood Bank ID
    lb2 = Label(labelFrame,text="Blood Bank : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.35, relheight=0.08)
        
    odInfo2 = Entry(labelFrame)
    odInfo2.place(relx=0.3,rely=0.35, relwidth=0.62, relheight=0.08)
        
    # Donation
    lb3 = Label(labelFrame,text="Blood/Plasma : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.50, relheight=0.08)
        
    odInfo3 = Entry(labelFrame)
    odInfo3.place(relx=0.3,rely=0.50, relwidth=0.62, relheight=0.08)
        
    # Donation Date
    lb4 = Label(labelFrame,text="Donation date : ", bg='black', fg='white')
    lb4.place(relx=0.05,rely=0.65, relheight=0.08)
        
    odInfo4 = Entry(labelFrame)
    odInfo4.place(relx=0.3,rely=0.65, relwidth=0.62, relheight=0.08)
        
    #Submit Button
    SubmitBtn = Button(root,text="DONATE",bg='#51B3AF', fg='black',command=old_donor)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#51B3AF', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
##--------------------------------------------------PATIENT--------------------------------------------------##

def PatientRegister():
    
    Pid = PInfo1.get()
    PFname = PInfo2.get()
    PLname = PInfo3.get()
    PBG = PInfo4.get()
    PAge = PInfo5.get()
    PGender = PInfo6.get()
    Pcontact = PInfo7.get()
    hid = PInfo8.get()
    Padd = PInfo9.get()
    
    insertP = "insert into "+Patient_Table+" values('"+Pid+"','"+PFname+"','"+PLname+"','"+PBG+"','"+PAge+"','"+PGender+"','"+Pcontact+"','"+Padd+"','"+hid+"')"
        
    try:
        cur.execute(insertP)
        con.commit()
        messagebox.showinfo('Success',"Patient added successfully")
    except:
        messagebox.showinfo("Error","Can't add data into Database")
        
def RemovePatient():
    
    hid = PatientRem.get()
    
    Gives_to_Table = "Gives_to"

    deleteG = "delete from "+Gives_to_Table+" where P_ID = '"+hid+"'"
    deleteH = "delete from "+Patient_Table+" where P_id = '"+hid+"'"

    try:
        cur.execute(deleteG)
        con.commit()
        cur.execute(deleteH)
        con.commit()
        messagebox.showinfo('Success',"Patient Deleted Successfully")
    except:
        messagebox.showinfo('Error',"Please check Patient ID")

    PatientRem.delete(0, END)
    root.destroy() 
        
def View_Patient(): 
    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()
    
    root = Tk()
    root.title("Patients")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Patient_Table = "Patients"

    Canvas1 = Canvas(root) 
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Patients", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    y = 0.25
    
    Label(labelFrame, text="%-20s%-40s%-30s%-20s%-20s%-20s"%('Patient ID','Name','Blood Group','Age','Gender','Hospital ID'),bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text="-------------------------------------------------------------------------------------------------------------------",bg='black',fg='white').place(relx=0.05,rely=0.2)
    getPatients = "select * from "+Patient_Table
    try:
        cur.execute(getPatients)
        con.commit()
        for i in cur:
            Label(labelFrame, text="%-30s%-50s%-35s%-25s%-25s%-20s"%(i[0],i[1]+" "+i[2],i[3],i[4],i[5],i[8]),bg='black',fg='white').place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    AddBtn = Button(root,text="Add",bg='#EC9DA3', fg='black',command=add_Patient)
    AddBtn.place(relx=0.21,rely=0.9, relwidth=0.18,relheight=0.08)
    
    RemoveBtn = Button(root,text="Remove",bg='#EC9DA3', fg='black', command=delete_Patient)
    RemoveBtn.place(relx=0.41,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.61,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

def insert_gives_to():
    bid = Bid.get()
    take = takes.get()
    pid = Pid.get()
    
    Gives_to_Table = "Gives_to"
    
    insertDetails = "insert into "+Gives_to_Table+" values('"+bid+"','"+pid+"','"+take+"')" 
    
    try:
        cur.execute(insertDetails)
        con.commit()
        messagebox.showinfo('Success',"Information added successfully")
    except:
        messagebox.showinfo("Error","Can't add data into Database")

def add_Patient(): 
    
    global PInfo1,PInfo2,PInfo3,PInfo4,PInfo5,PInfo6,PInfo8,PInfo7,PInfo9,Canvas1,con,cur,Patient_Table,root
    
    root = Tk()
    root.title("Patient")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    my_password = "password"
    my_database = "blood_plasma_donation"

    Patient_Table = "Patients"
    
    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

    headingLabel = Label(headingFrame1, text="Patient Details", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
        
    # Patient IP
    lb1 = Label(labelFrame,text="Patient IP : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.1, relheight=0.08)
        
    PInfo1 = Entry(labelFrame)
    PInfo1.place(relx=0.3,rely=0.1, relwidth=0.62, relheight=0.08)
        
    # First Name
    lb2 = Label(labelFrame,text="First Name : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.2, relheight=0.08)
        
    PInfo2 = Entry(labelFrame)
    PInfo2.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
    
    # Last Name
    lb3 = Label(labelFrame,text="Last Name : ", bg='black', fg='white')
    lb3.place(relx=0.05,rely=0.3, relheight=0.08)
        
    PInfo3 = Entry(labelFrame)
    PInfo3.place(relx=0.3,rely=0.3, relwidth=0.62, relheight=0.08)
        
    # Blood Group
    lb4 = Label(labelFrame,text="Blood Group : ", bg='black', fg='white')
    lb4.place(relx=0.05,rely=0.4, relheight=0.08)
        
    PInfo4 = Entry(labelFrame)
    PInfo4.place(relx=0.3,rely=0.4, relwidth=0.62, relheight=0.08)
        
    # Age
    lb5 = Label(labelFrame,text="Age : ", bg='black', fg='white')
    lb5.place(relx=0.05,rely=0.5, relheight=0.08)
        
    PInfo5 = Entry(labelFrame)
    PInfo5.place(relx=0.3,rely=0.5, relwidth=0.62, relheight=0.08)
    
    # Gender
    lb6 = Label(labelFrame,text="Gender : ", bg='black', fg='white')
    lb6.place(relx=0.05,rely=0.6, relheight=0.08)
        
    PInfo6 = Entry(labelFrame)
    PInfo6.place(relx=0.3,rely=0.6, relwidth=0.62, relheight=0.08)
    
    # Contact No.
    lb7 = Label(labelFrame,text="Phone No. : ", bg='black', fg='white')
    lb7.place(relx=0.05,rely=0.7, relheight=0.08)
        
    PInfo7 = Entry(labelFrame)
    PInfo7.place(relx=0.3,rely=0.7, relwidth=0.62, relheight=0.08)
    
    # Hospital ID
    lb8 = Label(labelFrame,text="H_ID : ", bg='black', fg='white')
    lb8.place(relx=0.05,rely=0.8, relheight=0.08)
        
    PInfo8 = Entry(labelFrame)
    PInfo8.place(relx=0.3,rely=0.8, relwidth=0.62, relheight=0.08)
    
    # Address
    lb9 = Label(labelFrame,text="Address : ", bg='black', fg='white')
    lb9.place(relx=0.05,rely=0.9, relheight=0.08)
        
    PInfo9 = Entry(labelFrame)
    PInfo9.place(relx=0.3,rely=0.9, relwidth=0.62, relheight=0.08)
        
    AddBtn = Button(root,text="Add",bg='#EC9DA3', fg='black',command=PatientRegister)
    AddBtn.place(relx=0.11,rely=0.9, relwidth=0.18,relheight=0.08)
    
    oldBtn = Button(root,text="Need Blood?", bg='#EC9DA3', fg='black', command = check_BG_view)
    oldBtn.place(relx=0.31,rely=0.9, relwidth=0.18,relheight=0.08)
    
    ViewBtn = Button(root,text="View Hospitals",bg='#EC9DA3', fg='black', command=View_Hospital)
    ViewBtn.place(relx=0.51,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.71,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

def delete_Patient(): 
    
    global PatientRem,Canvas1,con,cur,Patient_Table,root
    
    root = Tk()
    root.title("Patient")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Remove Patient", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)   
        
    # Patient ID to Delete
    lb2 = Label(labelFrame,text="Patient ID : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.5)
        
    PatientRem = Entry(labelFrame)
    PatientRem.place(relx=0.3,rely=0.5, relwidth=0.62)
    
    #Submit Button
    SubmitBtn = Button(root,text="Remove",bg='#EC9DA3', fg='black',command=RemovePatient)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
    
def check_BG():
    BG = BGreq.get()
    need = needs.get()
    my_password = "password"
    my_database = "blood_plasma_donation"
    Takes_from_Table = "Takes_from";
    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()
    
    root = Tk()
    root.title("Blood Bank")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")


    Canvas1 = Canvas(root) 
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Blood Banks", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    y = 0.25
    
    Label(labelFrame, text="%-20s%-20s%-20s%-20s"%('Blood Bank ID','Name','Contact No.','Location'),bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text="----------------------------------------------------------------------------",bg='black',fg='white').place(relx=0.05,rely=0.2)
    getBloodBanks = "select * from "+BloodBank_Table+" where B_ID in (select B_ID from "+Takes_from_Table+" where Donation = '"+need+"' and D_ID in (select D_ID from Donor where DBloodGroup = '"+BG+"'))"
    
    try:
        cur.execute(getBloodBanks)
        con.commit()
        for i in cur:
            Label(labelFrame, text="%-10s%-30s%-30s%-20s"%(i[0],i[1],i[2],i[3]),bg='black',fg='white').place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo('Error',"Failed to fetch files from database")
    
    AddBtn = Button(root,text="Take Blood",bg='#EC9DA3', fg='black',command=Take_blood)
    AddBtn.place(relx=0.21,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.61,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
    
def Take_blood():
    
    global Bid, takes, Pid
    
    root = Tk()
    root.title("Patient")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.1)
        
    headingLabel = Label(headingFrame1, text="Take Blood", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.25,relwidth=0.8,relheight=0.2)   
        
    # Blood Group to search
    lb2 = Label(labelFrame,text="Blood Bank ID : ", bg='black', fg='white')
    lb2.place(relx=0.02,rely=0.25)
        
    Bid = Entry(labelFrame)
    Bid.place(relx=0.3,rely=0.25, relwidth=0.62)
    
    lb3 = Label(labelFrame,text="Blood/Plasma : ", bg='black', fg='white')
    lb3.place(relx=0.02,rely=0.45)
        
    takes = Entry(labelFrame)
    takes.place(relx=0.3,rely=0.45, relwidth=0.62)
    
    lb4 = Label(labelFrame,text="Patient ID : ", bg='black', fg='white')
    lb4.place(relx=0.02,rely=0.65)
        
    Pid = Entry(labelFrame)
    Pid.place(relx=0.3,rely=0.65, relwidth=0.62)
    
    SubmitBtn = Button(root,text="Submit",bg='#EC9DA3', fg='black',command=insert_gives_to)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()    
    
def check_BG_view():
    
    global BGreq, needs
    
    root = Tk()
    root.title("Blood Group Match")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.1)
        
    headingLabel = Label(headingFrame1, text="Blood Group Match", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.25,relwidth=0.8,relheight=0.2)   
        
    # Blood Group to search
    lb2 = Label(labelFrame,text="Blood Group : ", bg='black', fg='white')
    lb2.place(relx=0.02,rely=0.25)
        
    BGreq = Entry(labelFrame)
    BGreq.place(relx=0.3,rely=0.25, relwidth=0.62)
    
    lb3 = Label(labelFrame,text="Blood/Plasma : ", bg='black', fg='white')
    lb3.place(relx=0.02,rely=0.65)
        
    needs = Entry(labelFrame)
    needs.place(relx=0.3,rely=0.65, relwidth=0.62)
    
    SubmitBtn = Button(root,text="Check",bg='#EC9DA3', fg='black',command=check_BG)
    SubmitBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
##--------------------------------------------------Take_from/Give_to--------------------------------------------------##

def view_donations():
    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()
    
    root = Tk()
    root.title("Donations")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Takes_from_Table = "Takes_from"

    Canvas1 = Canvas(root) 
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Donations", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    y = 0.25
    
    Label(labelFrame, text="%-20s%-30s%-30s%-20s"%('Blood Bank ID','Donor ID','Blood/Plasma','Donation Date'),bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text="---------------------------------------------------------------------------------------",bg='black',fg='white').place(relx=0.05,rely=0.2)
    gettable = "select * from "+Takes_from_Table
    try:
        cur.execute(gettable)
        con.commit()
        for i in cur:
            Label(labelFrame, text="%-35s%-40s%-30s%-20s"%(i[0],i[1],i[2],i[3]),bg='black',fg='white').place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.41,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()
    
def view_transactions():
    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()
    
    root = Tk()
    root.title("Transactions")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    Gives_to_Table = "Gives_to"

    Canvas1 = Canvas(root) 
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)
        
    headingLabel = Label(headingFrame1, text="Transactions", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
    
    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.3,relwidth=0.8,relheight=0.5)
    y = 0.25
    
    Label(labelFrame, text="%-20s%-30s%-30s"%('Blood Bank ID','Patient ID','Blood/Plasma'),bg='black',fg='white').place(relx=0.07,rely=0.1)
    Label(labelFrame, text="----------------------------------------------------------------------------",bg='black',fg='white').place(relx=0.05,rely=0.2)
    gettable = "select * from "+Gives_to_Table
    try:
        cur.execute(gettable)
        con.commit()
        for i in cur:
            Label(labelFrame, text="%-30s%-40s%-30s"%(i[0],i[1],i[2]),bg='black',fg='white').place(relx=0.07,rely=y)
            y += 0.1
    except:
        messagebox.showinfo("Failed to fetch files from database")
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.40,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
##--------------------------------------------------ADMIN--------------------------------------------------##

AdminTable = "Administrator" # Administrator Table

def Admin_View():
    
    root = Tk()
    root.title("Admin")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    my_password = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=my_password,database=my_database)
    cur = con.cursor()

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
    
    headingFrame1 = Frame(root, bg="#EC9DA3",bd = 5)
    headingFrame1.place(relx = 0.2, rely = 0.1,relwidth=0.6,relheight=0.16)

    headingLabel = Label(headingFrame1, text="Admin View", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    btn1 = Button(root,text="Hospitals",bg='black', fg='white', command = View_Hospital)
    btn1.place(relx=0.28,rely=0.3, relwidth=0.45,relheight=0.09)
    
    btn2 = Button(root,text="Blood Banks",bg='black', fg='white', command = View_BloodBank)
    btn2.place(relx=0.28,rely=0.4, relwidth=0.45,relheight=0.09)
    
    btn3 = Button(root,text="Patients",bg='black', fg='white', command = View_Patient)
    btn3.place(relx=0.28,rely=0.5, relwidth=0.45,relheight=0.09)
    
    btn4 = Button(root,text="Donors",bg='black', fg='white', command = View_Donor)
    btn4.place(relx=0.28,rely=0.6, relwidth=0.45,relheight=0.09)
    
    btn4 = Button(root,text="Donations",bg='black', fg='white', command = view_donations)
    btn4.place(relx=0.28,rely=0.7, relwidth=0.45,relheight=0.09)
    
    btn4 = Button(root,text="Transfusion",bg='black', fg='white', command = view_transactions)
    btn4.place(relx=0.28,rely=0.8, relwidth=0.45,relheight=0.09)
    
    quitBtn = Button(root,text="Logout",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.41,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

def allow_access():
    
    A_username = user_label.get()
    A_password = password_label.get()
    
    access_query = "select username from "+AdminTable+" where passwd = '"+A_password+"'"
    
    try:
        cur.execute(access_query)
        con.commit()
        for i in cur:
            if A_username == i[0]:
                messagebox.showinfo('Success', A_username + " logged in")
                Admin_View()
            else:
                messagebox.showinfo("Error","The information you entered is incorrect")
    except:
        messagebox.showinfo("Error","The information you entered is incorrect")

def Admin():
    global user_label, password_label, Canvas1,con,cur,root
    
    root = Tk()
    root.title("Admin")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")

    mypass = "password"
    my_database = "blood_plasma_donation"

    con = pymysql.connect(host="localhost",user="root",password=mypass,database=my_database)
    cur = con.cursor()

    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="#8897B0")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="#EC9DA3",bd=5)
    headingFrame1.place(relx=0.25,rely=0.1,relwidth=0.5,relheight=0.13)

    headingLabel = Label(headingFrame1, text="Admin Login", bg='black', fg='white', font=('Courier',15))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)


    labelFrame = Frame(root,bg='black')
    labelFrame.place(relx=0.1,rely=0.4,relwidth=0.8,relheight=0.4)
    
    # Username
    lb1 = Label(labelFrame,text="Username : ", bg='black', fg='white')
    lb1.place(relx=0.05,rely=0.2, relheight=0.08)
    
    user_label = Entry(labelFrame)
    user_label.place(relx=0.3,rely=0.2, relwidth=0.62, relheight=0.08)
        
    # Password
    lb2 = Label(labelFrame,text="Password : ", bg='black', fg='white')
    lb2.place(relx=0.05,rely=0.35, relheight=0.08)
        
    password_label = Entry(labelFrame, show="*")
    password_label.place(relx=0.3,rely=0.35, relwidth=0.62, relheight=0.08)
        

    LoginBtn = Button(root,text="Login",bg='#EC9DA3', fg='black',command=allow_access)
    LoginBtn.place(relx=0.28,rely=0.9, relwidth=0.18,relheight=0.08)
    
    quitBtn = Button(root,text="Quit",bg='#EC9DA3', fg='black', command=root.destroy)
    quitBtn.place(relx=0.53,rely=0.9, relwidth=0.18,relheight=0.08)
    
    root.mainloop()

# %%
##--------------------------------------------------MAIN--------------------------------------------------##

root = Tk()
root.title("Blood and Plasma Donation")
root.minsize(width=400,height=400)
root.geometry("1000x600")

Canvas1 = Canvas(root)

Canvas1.config(bg="#8897B0")
Canvas1.pack(expand=True,fill=BOTH)

headingFrame1 = Frame(root, bg="#EC9DA3",bd = 5)
headingFrame1.place(relx = 0.2, rely = 0.1,relwidth=0.6,relheight=0.16)

headingLabel = Label(headingFrame1, text="Blood and\n Plasma Donation", bg='black', fg='white', font=('Courier',15))
headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

btn1 = Button(root,text="Donor",bg='black', fg='white', font=('Courier',15), command = add_Donor)
btn1.place(relx=0.28,rely=0.4, relwidth=0.45,relheight=0.1)
    
btn2 = Button(root,text="Patient",bg='black', fg='white',font=('Courier',15), command = add_Patient)
btn2.place(relx=0.28,rely=0.55, relwidth=0.45,relheight=0.1)
    
btn3 = Button(root,text="Admin",bg='black', fg='white',font=('Courier',15), command=Admin)
btn3.place(relx=0.28,rely=0.7, relwidth=0.45,relheight=0.1)
 
root.mainloop()
